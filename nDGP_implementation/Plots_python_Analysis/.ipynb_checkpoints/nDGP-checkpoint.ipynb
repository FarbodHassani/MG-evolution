# %% [markdown]
# # Notebook for comparison beween  Gevolution and class and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
import scipy.integrate as integrate
tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
             (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
             (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau12)):    
    r, g, b = tableau12[i]    
    tableau_color = ["red","blue","black","purple","orange","cyan","magenta"] 
    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
# plt.style.available
plt.rcParams.update(plt.rcParamsDefault)

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %%
Bg_ndgp=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_background.dat")
Bg_lcdm_newt =np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_background.dat")
#power

addressGev_lcdm="./CSCS_Results/Results_LCDM/output/";
Gev_nl_zeta_zall=[]
Gev_nl_Hpi_zall=[]
Gev_nl_phi_zall=[]
z_list=[100,50, 30, 10, 3, 1, 0]
maxNum=np.shape(z_list)[0]
for i in range (0,maxNum):
    pow_newt_phi_z_all.append(np.loadtxt("./"+addressGev_lcdm+"/kess_pk_cs_0_"+str(i).zfill(3)+"_zeta.dat"))
    Gev_nl_Hpi_zall.append(np.loadtxt("./"+addressGev+"/kess_pk_cs_0_"+str(i).zfill(3)+"_pi_k.dat"))
    Gev_nl_phi_zall.append(np.loadtxt("./"+addressGev+"/kess_pk_cs_0_"+str(i).zfill(3)+"_phi.dat") )
average=np.loadtxt("./"+addressGev+"/Result_avg.txt")

pow_newt_phi_z_0=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk000_phi.dat")
pow_ndgp_phi_z_0=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk000_phi.dat")
pow_newt_delta_z_0=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk000_delta.dat")
pow_ndgp_delta_z_0=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk000_delta.dat")

# pow_newt_phi_z_1=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk001_phi.dat")
# pow_ndgp_phi_z_1=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk001_phi.dat")
# pow_newt_delta_z_1=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk001_delta.dat")
# pow_ndgp_delta_z_1=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk001_delta.dat")


# pow_newt_phi_z_2=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk002_phi.dat")
# pow_ndgp_phi_z_2=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk002_phi.dat")
# pow_newt_delta_z_2=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk002_delta.dat")
# pow_ndgp_delta_z_2=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk002_delta.dat")

# pow_newt_phi_z_3=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk003_phi.dat")
# pow_ndgp_phi_z_3=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk003_phi.dat")
# pow_newt_delta_z_3=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk003_delta.dat")
# pow_ndgp_delta_z_3=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk003_delta.dat")

# pow_newt_phi_z_4=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk004_phi.dat")
# pow_ndgp_phi_z_4=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk004_phi.dat")
# pow_newt_delta_z_4=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk004_delta.dat")
# pow_ndgp_delta_z_4=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk004_delta.dat")

# pow_newt_phi_z_5=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk005_phi.dat")
# pow_ndgp_phi_z_5=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk005_phi.dat")
# pow_newt_delta_z_5=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk005_delta.dat")
# pow_ndgp_delta_z_5=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk005_delta.dat")

# pow_newt_phi_z_6=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk006_phi.dat")
# pow_ndgp_phi_z_6=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk006_phi.dat")
# pow_newt_delta_z_6=np.loadtxt("./CSCS_Results/Results_LCDM/output/lcdm_newt_pk006_delta.dat")
# pow_ndgp_delta_z_6=np.loadtxt("./CSCS_Results/Results_nDGP/output/ndgp_pk006_delta.dat")

# pow_newt_phi_zall=[pow_newt_phi_z_0,pow_newt_phi_z_1,pow_newt_phi_z_2,pow_newt_phi_z_3,pow_newt_phi_z_4,
#                    pow_newt_phi_z_5,pow_newt_phi_z_6]
# pow_ndgp_phi_zall=[pow_ndgp_phi_z_0,pow_ndgp_phi_z_1,pow_ndgp_phi_z_2,pow_ndgp_phi_z_3,pow_ndgp_phi_z_4
#                  ,pow_ndgp_phi_z_5,pow_ndgp_phi_z_6]
# pow_newt_delta_zall=[pow_newt_delta_z_0,pow_newt_delta_z_1,pow_newt_delta_z_2,pow_newt_delta_z_3,pow_newt_delta_z_4,
#                   pow_newt_delta_z_5,pow_newt_delta_z_6]

# pow_ndgp_delta_zall=[pow_ndgp_delta_z_0,pow_ndgp_delta_z_1,pow_ndgp_delta_z_2,pow_ndgp_delta_z_3,pow_ndgp_delta_z_4,
#                    pow_ndgp_delta_z_5,pow_ndgp_delta_z_6]

# %% [markdown]
# # DGP Background

# %%
def Hubble_conf_Mpc_ndgp(a):
    h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;Omega_DGP=0.11289;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.1671353942930788e-05; 
    return H0* (np.sqrt(Omega_DGP) +np.sqrt(Omega_DGP + Omega_m*(a**-3)+Omega_rad*(a**-4)) )*a
alist=np.arange(0, 100, 0.005)
h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#*******************
#Subplot I
plt.subplot(211)
plt.figure(1)
# plt.loglog(Bg_ndgp[:,2],Hubble_conf_Mpc_ndgp(Bg_ndgp[:,2])/H0,color="red",linestyle='solid',lw=1.5,label=r"$DGP\_formula$")

plt.loglog(Bg_ndgp[:,2],Bg_ndgp[:,3],color="blue",linestyle='solid',lw=1.5,label=r"$DGP\_evolution$")

plt.loglog(Bg_lcdm_newt[:,2],Bg_lcdm_newt[:,3],color="black",linestyle='solid',lw=1.5,label=r"$GR-LCDM$")
plt.legend(bbox_to_anchor=(.7, 0.70, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)

plt.xlabel("a",fontsize=18)
plt.ylabel(r"$\mathcal{H}(z)/\mathcal{H}_0$",fontsize=18)
# plt.ylabel('log')
# plt.xlabel('log')
# plt.grid(True)
# plt.savefig('./Hubble_present.jpg', format='jpg', dpi=200)

plt.show()

# %% [markdown]
# # Phi power spectrum Plots

# %%
plt.figure(figsize=(15,15))
z_list=[100, 50, 30,10, 3, 1, 0]

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
x = np.linspace(0, 10, 1000)

plt.subplot(211)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
for i in range (0,7):
#     plt.loglog(pow_gr_phi_zall[i][:,0], pow_gr_phi_zall[i][:,1],color=tableau20[i],linestyle='dashed',lw=2.5, label=r"$\Phi$(ndgp),  z="+str(z_list[i]) )
    plt.semilogx(pow_ndgp_phi_zall[i][:1024,0], pow_ndgp_phi_zall[i][:1024,1]/pow_newt_phi_zall[i][:,1],color=tableau_color[i],linestyle='solid',lw=2.5,label=r"$\frac{\mathcal{P}_{\Phi}(ndgp)}{\mathcal{P}_{\Phi}(GR)}$, z= "+str(z_list[i]) )
    plt.axvspan(0., 14, alpha=0.5, color='pink')

# plt.loglog(power_gr_phi_zall[i+1][:,0], power_gr_phi_zall[i+1][:,1],color="red",linestyle='dashed',lw=2.5, label=r"$\Phi$(ndgp),  z="+str(z_list[i+1]) )
# plt.loglog(pow_ndgp_phi_zall[i+1][:,0], pow_ndgp_phi_zall[i+1][:,1],color="purple",linestyle='solid',lw=2.5,label=r"$\Phi$(GR), z= "+str(z_list[i+1]) )

plt.legend(bbox_to_anchor=(0.62, 0.78, 0.36, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P} $",fontsize=18)
plt.xlim(0.0088,0.7)
plt.ylim(0.,2.5)
plt.grid(True)


# ##Subplot 2
# plt.subplot(212)
# ax = plt.gca()
# ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
# ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
# for i in range (2,5):
#     plt.loglog(pow_gr_phi_zall[i][:,0], np.abs(pow_ndgp_phi_zall[i][:,1]-pow_gr_phi_zall[i+2][:,1])/pow_gr_phi_zall[i][:,1],color=tableau_color[i],linestyle='dashed',lw=2.5, label=r"$|\frac{\mathcal{P}_{\Phi}(ndgp) - \mathcal{P}_{\Phi} (GR)}{\mathcal{P}_{\Phi}(GR)}|$,  z="+str(z_list[i]) )
#     plt.axvspan(0.6, 14, alpha=0.5, color='pink')



# plt.legend(bbox_to_anchor=(0.02, 0.88, 0.36, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
# plt.xlabel("k[h/Mpc]",fontsize=18)
# # plt.ylabel(r"$\mathcal{P} $",fontsize=18)
# plt.xlim(0.0088,0.7)
# # plt.ylim(1.e-15,1.e-9)
# plt.grid(True)


# plt.savefig('./Gev-Class_Images/CsCs.jpg', format='jpg', dpi=100)
plt.show()
# Out:
# /Users/farbod/anaconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # matter power spectrum Plots

# %%
plt.figure(figsize=(15,15))
z_list=[100, 50, 30,10, 3, 1, 0]

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
plt.subplot(211)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
for i in range (3,7):
#     plt.loglog(pow_gr_phi_zall[i][:,0], pow_gr_phi_zall[i][:,1],color=tableau20[i],linestyle='dashed',lw=2.5, label=r"$\Phi$(ndgp),  z="+str(z_list[i]) )
    plt.semilogx(pow_newt_delta_zall[i][:,0], pow_ndgp_delta_zall[i][:1024,1]/pow_newt_delta_zall[i][:,1],color=tableau_color[i],linestyle='solid',lw=2.5,label=r"$\frac{\mathcal{P}_{\delta_m} (ndgp)}{\mathcal{P}_{\delta_m} (GR)}$, z= "+str(z_list[i]) )
#     plt.axvspan(0.6, 14, alpha=0.5, color='pink')
# plt.loglog(power_gr_phi_zall[i+1][:,0], power_gr_phi_zall[i+1][:,1],color="red",linestyle='dashed',lw=2.5, label=r"$\Phi$(ndgp),  z="+str(z_list[i+1]) )
# plt.loglog(pow_ndgp_phi_zall[i+1][:,0], pow_ndgp_phi_zall[i+1][:,1],color="purple",linestyle='solid',lw=2.5,label=r"$\Phi$(GR), z= "+str(z_list[i+1]) )
ax.hlines(y=1.25, xmin=0.01, xmax=20, linewidth=2, color='black')
ax.hlines(y=1.15, xmin=0.01, xmax=20, linewidth=2, color='black')


plt.legend(bbox_to_anchor=(0.02, 0.18, 0.26, .102), loc=1,ncol=1,fontsize=9, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P} $",fontsize=18)
plt.xlim(0.0088,20)
# plt.ylim(0,2.5)
plt.grid(True)


# ##Subplot 2
# plt.subplot(212)
# ax = plt.gca()
# ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
# ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
# for i in range (1,5):
#     plt.loglog(pow_gr_delta_zall[i][:,0], np.abs(pow_ndgp_delta_zall[i][:,1]-pow_gr_delta_zall[i+2][:,1])/pow_gr_delta_zall[i][:,1],color=tableau_color[i],linestyle='dashed',lw=2.5, label=r"$\frac{\mathcal{P}_{\delta_m} (ndgp) - \mathcal{P}_{\delta_m}(GR)}{\mathcal{P}_{\delta_m} (GR)}$,  z="+str(z_list[i]) )
#     plt.axvspan(0.6, 14, alpha=0.5, color='pink')


# plt.legend(bbox_to_anchor=(0.02, 0.88, 0.36, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
# plt.xlabel("k[h/Mpc]",fontsize=18)
# # plt.ylabel(r"$\mathcal{P} $",fontsize=18)
# plt.xlim(0.0088,0.7)
# # plt.ylim(1.e-15,1.e-9)
# plt.grid(True)


# plt.savefig('./Gev-Class_Images/CsCs.jpg', format='jpg', dpi=100)
plt.show()

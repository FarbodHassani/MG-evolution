# %% [markdown]
# # Notebook for comparison beween  Gevolution and class and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
import scipy.integrate as integrate
tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
             (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
             (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau12)):    
    r, g, b = tableau12[i]    
    tableau_color = ["red","blue","black","purple","orange","cyan","magenta"] 
    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
# plt.style.available
plt.rcParams.update(plt.rcParamsDefault)

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %%
Bg_dgp=np.loadtxt("./../DGP_evolution/output/dgp_background.dat")
Bg_lcdm_gr =np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_background.dat")
#power
pow_gr_phi_z_0=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk000_phi.dat")
pow_dgp_phi_z_0=np.loadtxt("./../DGP_evolution/output/dgp_pk000_phi.dat")
pow_gr_delta_z_0=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk000_delta.dat")
pow_dgp_delta_z_0=np.loadtxt("./../DGP_evolution/output/dgp_pk000_delta.dat")

pow_gr_phi_z_1=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk001_phi.dat")
pow_dgp_phi_z_1=np.loadtxt("./../DGP_evolution/output/dgp_pk001_phi.dat")
pow_gr_delta_z_1=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk001_delta.dat")
pow_dgp_delta_z_1=np.loadtxt("./../DGP_evolution/output/dgp_pk001_delta.dat")


pow_gr_phi_z_2=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk002_phi.dat")
pow_dgp_phi_z_2=np.loadtxt("./../DGP_evolution/output/dgp_pk002_phi.dat")
pow_gr_delta_z_2=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk002_delta.dat")
pow_dgp_delta_z_2=np.loadtxt("./../DGP_evolution/output/dgp_pk002_delta.dat")

pow_gr_phi_z_3=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk003_phi.dat")
pow_dgp_phi_z_3=np.loadtxt("./../DGP_evolution/output/dgp_pk003_phi.dat")
pow_gr_delta_z_3=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk003_delta.dat")
pow_dgp_delta_z_3=np.loadtxt("./../DGP_evolution/output/dgp_pk003_delta.dat")

pow_gr_phi_z_4=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk004_phi.dat")
pow_dgp_phi_z_4=np.loadtxt("./../DGP_evolution/output/dgp_pk004_phi.dat")
pow_gr_delta_z_4=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk004_delta.dat")
pow_dgp_delta_z_4=np.loadtxt("./../DGP_evolution/output/dgp_pk004_delta.dat")

pow_gr_phi_z_5=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk005_phi.dat")
pow_dgp_phi_z_5=np.loadtxt("./../DGP_evolution/output/dgp_pk005_phi.dat")
pow_gr_delta_z_5=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk005_delta.dat")
pow_dgp_delta_z_5=np.loadtxt("./../DGP_evolution/output/dgp_pk005_delta.dat")

pow_gr_phi_z_6=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk006_phi.dat")
pow_dgp_phi_z_6=np.loadtxt("./../DGP_evolution/output/dgp_pk006_phi.dat")
pow_gr_delta_z_6=np.loadtxt("./../DGP_evolution/GR_output/lcdm_gr_pk006_delta.dat")
pow_dgp_delta_z_6=np.loadtxt("./../DGP_evolution/output/dgp_pk006_delta.dat")

pow_gr_phi_zall=[pow_gr_phi_z_0,pow_gr_phi_z_1,pow_gr_phi_z_2,pow_gr_phi_z_3,pow_gr_phi_z_4,
                   pow_gr_phi_z_5,pow_gr_phi_z_6]
pow_dgp_phi_zall=[pow_dgp_phi_z_0,pow_dgp_phi_z_1,pow_dgp_phi_z_2,pow_dgp_phi_z_3,pow_dgp_phi_z_4
                 ,pow_dgp_phi_z_5,pow_dgp_phi_z_6]
pow_gr_delta_zall=[pow_gr_delta_z_0,pow_gr_delta_z_1,pow_gr_delta_z_2,pow_gr_delta_z_3,pow_gr_delta_z_4,
                  pow_gr_delta_z_5,pow_gr_delta_z_6]

pow_dgp_delta_zall=[pow_dgp_delta_z_0,pow_dgp_delta_z_1,pow_dgp_delta_z_2,pow_dgp_delta_z_3,pow_dgp_delta_z_4,
                   pow_dgp_delta_z_5,pow_dgp_delta_z_6]

# %% [markdown]
# # DGP Background

# %%
def Hubble_conf_Mpc_dgp(a):
    h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;Omega_DGP=0.11289;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.1671353942930788e-05; 
    return H0* (np.sqrt(Omega_DGP) +np.sqrt(Omega_DGP + Omega_m*(a**-3)+Omega_rad*(a**-4)) )*a
alist=np.arange(0, 100, 0.005)
h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#*******************
#Subplot I
plt.subplot(211)
plt.figure(1)
plt.loglog(Bg_dgp[:,2],Hubble_conf_Mpc_dgp(Bg_dgp[:,2])/H0,color="red",linestyle='solid',lw=1.5,label=r"$DGP\_formula$")

plt.loglog(Bg_dgp[:,2],Bg_dgp[:,3],color="blue",linestyle='solid',lw=1.5,label=r"$DGP\_evolution$")

plt.loglog(Bg_lcdm_gr[:,2],Bg_lcdm_gr[:,3],color="black",linestyle='solid',lw=1.5,label=r"$GR-LCDM$")
plt.legend(bbox_to_anchor=(.7, 0.70, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)

plt.xlabel("a",fontsize=18)
plt.ylabel(r"$\mathcal{H}(z)/\mathcal{H}_0$",fontsize=18)

plt.subplot(212)

plt.loglog(Bg_dgp[:,2],np.abs((Hubble_conf_Mpc_dgp(Bg_dgp[:,2])/H0-Bg_dgp[:,3])/(Bg_dgp[:,3]+Hubble_conf_Mpc_dgp(Bg_dgp[:,2])/H0)),color="olive",
           label=r"2|$\frac{\mathcal{H}(GDP\_ev)-\mathcal{H}(fomula)}{\mathcal{H}(GDP\_ev)+\mathcal{H}(fomula)}|$")

plt.legend(bbox_to_anchor=(.0, 0.70, 0.3, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)

plt.xlabel("a",fontsize=18)
plt.ylabel(r"$\mathcal{H}(z)/\mathcal{H}_0$",fontsize=18)

# plt.ylabel('log')
# plt.xlabel('log')
# plt.grid(True)
# plt.savefig('./Hubble_present.jpg', format='jpg', dpi=200)

plt.show()

# %% [markdown]
# # Phi power spectrum Plots

# %%
plt.figure(figsize=(15,15))
z_list=[100, 50, 30,10, 3, 1, 0]

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
plt.subplot(211)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
for i in range (2,6):
#     plt.loglog(pow_gr_phi_zall[i][:,0], pow_gr_phi_zall[i][:,1],color=tableau20[i],linestyle='dashed',lw=2.5, label=r"$\Phi$(DGP),  z="+str(z_list[i]) )
    plt.loglog(pow_dgp_phi_zall[i][:,0], pow_dgp_phi_zall[i][:,1]/pow_gr_phi_zall[i][:,1],color=tableau_color[i],linestyle='solid',lw=2.5,label=r"$\frac{\mathcal{P}_{\Phi}(DGP)}{\mathcal{P}_{\Phi}(GR)}$, z= "+str(z_list[i]) )
    plt.axvspan(0.6, 14, alpha=0.5, color='pink')

# plt.loglog(power_gr_phi_zall[i+1][:,0], power_gr_phi_zall[i+1][:,1],color="red",linestyle='dashed',lw=2.5, label=r"$\Phi$(DGP),  z="+str(z_list[i+1]) )
# plt.loglog(pow_dgp_phi_zall[i+1][:,0], pow_dgp_phi_zall[i+1][:,1],color="purple",linestyle='solid',lw=2.5,label=r"$\Phi$(GR), z= "+str(z_list[i+1]) )


plt.legend(bbox_to_anchor=(0.02, 0.28, 0.36, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P} $",fontsize=18)
plt.xlim(0.0088,0.7)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)


##Subplot 2
plt.subplot(212)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
for i in range (2,5):
    plt.loglog(pow_gr_phi_zall[i][:,0], np.abs(pow_dgp_phi_zall[i][:,1]-pow_gr_phi_zall[i+2][:,1])/pow_gr_phi_zall[i][:,1],color=tableau_color[i],linestyle='dashed',lw=2.5, label=r"$|\frac{\mathcal{P}_{\Phi}(DGP) - \mathcal{P}_{\Phi} (GR)}{\mathcal{P}_{\Phi}(GR)}|$,  z="+str(z_list[i]) )
    plt.axvspan(0.6, 14, alpha=0.5, color='pink')



plt.legend(bbox_to_anchor=(0.02, 0.88, 0.36, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
# plt.ylabel(r"$\mathcal{P} $",fontsize=18)
plt.xlim(0.0088,0.7)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)


# plt.savefig('./Gev-Class_Images/CsCs.jpg', format='jpg', dpi=100)
plt.show()

# %% [markdown]
# # matter power spectrum Plots

# %%
plt.figure(figsize=(15,15))
z_list=[100, 50, 30,10, 3, 1, 0]

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
plt.subplot(211)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
for i in range (3,6):
#     plt.loglog(pow_gr_phi_zall[i][:,0], pow_gr_phi_zall[i][:,1],color=tableau20[i],linestyle='dashed',lw=2.5, label=r"$\Phi$(DGP),  z="+str(z_list[i]) )
    plt.loglog(pow_gr_delta_zall[i][:,0], pow_dgp_delta_zall[i][:,1]/pow_gr_delta_zall[i][:,1],color=tableau_color[i],linestyle='solid',lw=2.5,label=r"$\frac{\mathcal{P}_{\delta_m} (DGP)}{\mathcal{P}_{\delta_m} (GR)}$, z= "+str(z_list[i]) )
    plt.axvspan(0.6, 14, alpha=0.5, color='pink')
# plt.loglog(power_gr_phi_zall[i+1][:,0], power_gr_phi_zall[i+1][:,1],color="red",linestyle='dashed',lw=2.5, label=r"$\Phi$(DGP),  z="+str(z_list[i+1]) )
# plt.loglog(pow_dgp_phi_zall[i+1][:,0], pow_dgp_phi_zall[i+1][:,1],color="purple",linestyle='solid',lw=2.5,label=r"$\Phi$(GR), z= "+str(z_list[i+1]) )


plt.legend(bbox_to_anchor=(0.02, 0.88, 0.36, .102), loc=1,ncol=1,fontsize=14, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
plt.ylabel(r"$\mathcal{P} $",fontsize=18)
plt.xlim(0.0088,0.7)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)


##Subplot 2
plt.subplot(212)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 18)
for i in range (1,5):
    plt.loglog(pow_gr_delta_zall[i][:,0], np.abs(pow_dgp_delta_zall[i][:,1]-pow_gr_delta_zall[i+2][:,1])/pow_gr_delta_zall[i][:,1],color=tableau_color[i],linestyle='dashed',lw=2.5, label=r"$\frac{\mathcal{P}_{\delta_m} (DGP) - \mathcal{P}_{\delta_m}(GR)}{\mathcal{P}_{\delta_m} (GR)}$,  z="+str(z_list[i]) )
    plt.axvspan(0.6, 14, alpha=0.5, color='pink')


plt.legend(bbox_to_anchor=(0.02, 0.88, 0.36, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=18)
# plt.ylabel(r"$\mathcal{P} $",fontsize=18)
plt.xlim(0.0088,0.7)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)


# plt.savefig('./Gev-Class_Images/CsCs.jpg', format='jpg', dpi=100)
plt.show()
